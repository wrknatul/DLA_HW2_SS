# %%
import os
from pathlib import Path
from kaggle_secrets import UserSecretsClient

github_username= "wrknatul"
github_repository= "DLA_HW2_SS"

private_key_content = UserSecretsClient().get_secret("GITHUB_SSH_KEY")
key_lines = [
    "-----BEGIN OPENSSH PRIVATE KEY-----",
    *private_key_content.strip().split(' '),
    "-----END OPENSSH PRIVATE KEY-----\n"
]
formatted_key = "\n".join(key_lines)

private_key_path = Path('/root/.ssh/id_rsa')
private_key_path.parent.mkdir(parents=True, exist_ok=True)
private_key_path.write_text(formatted_key)
private_key_path.chmod(0o600)

# !ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
# !GIT_SSH_COMMAND="ssh -i {private_key_path}" git clone git@github.com:wrknatul/DLA_HW2_SS.git


# !ls -la {github_repository}
# Out:
# ---------------------------------------------------------------------------
# BackendError                              Traceback (most recent call last)
# Cell In[5], line 8
#       5 github_username= "wrknatul"
#       6 github_repository= "DLA_HW2_SS"
# ----> 8 private_key_content = UserSecretsClient().get_secret("GITHUB_SSH_KEY")
#       9 key_lines = [
#      10     "-----BEGIN OPENSSH PRIVATE KEY-----",
#      11     *private_key_content.strip().split(' '),
#      12     "-----END OPENSSH PRIVATE KEY-----\n"
#      13 ]
#      14 formatted_key = "\n".join(key_lines)
#
# File ~/.local/lib/python3.10/site-packages/kaggle_secrets.py:64, in UserSecretsClient.get_secret(self, label)
#      60     raise ValidationError("Label must be non-empty.")
#      61 request_body = {
#      62     'Label': label,
#      63 }
# ---> 64 response_json = self.web_client.make_post_request(request_body, self.GET_USER_SECRET_BY_LABEL_ENDPOINT)
#      65 if 'secret' not in response_json:
# ...

# %%
# !ssh-keygen -t rsa
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/root/.ssh/id_rsa): ^C
